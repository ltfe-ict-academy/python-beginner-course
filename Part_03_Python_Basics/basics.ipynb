# %% [markdown]
# # Dan 1
#
# Markdown: https://www.markdownguide.org/getting-started/

# %%
print("Test")
# Out:
# Test

# %% [markdown]
# ## Basic Data Types

# %%
print(5) # integer
# Out:
# 5

# %%
print(3.12) # float
# Out:
# 3.12

# %%
print('On je rekel: "Pazi!"') # string with quotes
# Out:
# On je rekel: "Pazi!"

# %%
print(True) # boolean
print(False) # boolean
# Out:
# True
# False

# %%
print(type(34))
print(type(3.14))
print(type("Hello"))
print(type(True))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
print(int(3.99))
# Out:
# 3

# %%
print(int(float("42.43")))
# Out:
# 42

# %%
print(float(4))
# Out:
# 4.0

# %%
print(type(str(3434)))
# Out:
# <class 'str'>

# %%
print(bool(34))
print(bool(0.3434))
print(bool("sddfsdds"))
print(bool(""))
print(bool(0.0))
print(bool(0))
# Out:
# True
# True
# True
# False
# False
# False

# %% [markdown]
# ## Variables
#
# - Variables in Python are symbolic names pointing to objects or values in memory.
# - You define variables by assigning them a value using the assignment operator.
# - Python variables are dynamically typed, allowing type changes through reassignment.
# - Python variable names can include letters, digits, and underscores but can’t start with a digit. You should use snake case for multi-word names to improve readability.
# - Variables are case-sensitive. Lowercase and uppercase letters aren’t treated the same.
# - You can have an unlimited number of variables in Python, limited only by computer memory.

# %%
temperatura_sobe_01 = 23.5

# %%
input("Vpiši število: ")
# Out:
# '4'

# %%
4 > 56
# Out:
# False

# %%
"aa" != "bb"
# Out:
# True

# %%
a = True
a == True
# Out:
# True

# %%
a = 4
pogoj_01 = a > 7
pogoj_02 = a <= 10
print(pogoj_01 and pogoj_02)
print(pogoj_01 or pogoj_02)
print(not pogoj_01)
# Out:
# False
# True
# True

# %%
x = 1001
y = 1001

print(x == y)
print(x is y) # id(x) == id(y)
print(id(x))
print(id(y))

c = x

print(x == c)
print(x is c)
print(id(x), id(c))

print("----------")
x=2
print("X=", x, "c=",c)
print(id(x), id(c))
# Out:
# True
# False
# 2433284619024
# 2433284770256
# True
# True
# 2433284619024 2433284619024
# ----------
# X= 2 c= 1001
# 140709092447384 2433284619024

# %%
0.333 * 3 == 0.999
# Out:
# False

# %%
0.333 * 3
# Out:
# 0.9990000000000001

# %%
ime = "Luka"
starost = 35
visina = 175.6

# Želimo: Oseba Luka je stara 35 let in visoka 176cm.

print("Oseba", ime, "je stara", starost, "in visok", round(visina), "cm.")

# Staro in se ne uporablja več
print("Oseba {} je stara {}".format(ime, starost))

# Nov način
print(f"Oseba {ime} je stara {starost} in visoka {round(visina)}cm.")
# Out:
# Oseba Luka je stara 35 in visok 176 cm.
# Oseba Luka je stara 35
# Oseba Luka je stara 35 in visoka 176cm.
